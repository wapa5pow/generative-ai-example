# %%
from openai import OpenAI
import requests

client = OpenAI()

quality = ["standard", "hd"]
styles = ["vivid", "natural"]
images = []
labels = []

for q in quality:
    for s in styles:
        response = client.images.generate(
            model="dall-e-3",
            prompt="A cute baby sea otter",
            n=1,
            size="1024x1024",
            response_format="url",
            style=s,
            quality=q,
            user="wapa5pow",
        )

        data = requests.get(response.data[0].url).content
        label = f"{q}_{s}"
        filename = f"data/openai_dall-e-3_{label}.png"
        with open(filename, "wb") as handler:
            handler.write(data)
        images.append(filename)
        labels.append(label)

# %%
import ipyplot

ipyplot.plot_images(images, labels=labels, max_images=300, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-aFBzno3tmNNrPRhFTYEeN9 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-aFBzno3tmNNrPRhFTYEeN9 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-aFBzno3tmNNrPRhFTYEeN9 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-aFBzno3tmNNrPRhFTYEeN9:checked ~ #ipyplot-html-viewer-textarea-aFBzno3tmNNrPRhFTYEeN9 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-aFBzno3tmNNrPRhFTYEeN9:checked + #ipyplot-html-viewer-label-aFBzno3tmNNrPRhFTYEeN9:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-aFBzno3tmNNrPRhFTYEeN9">
#         <label id="ipyplot-html-viewer-label-aFBzno3tmNNrPRhFTYEeN9" for="ipyplot-html-viewer-toggle-aFBzno3tmNNrPRhFTYEeN9">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-aFBzno3tmNNrPRhFTYEeN9" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-AxCtLj4vrXxWwJgYdpBHRk {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-AxCtLj4vrXxWwJgYdpBHRk">
#     <div class="ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk">
#         <div id="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-Jb7JteoLCiQXABLxGCzg6o" class="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">standard_vivid</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/openai_dall-e-3_standard_vivid.png</h4><img src="data/openai_dall-e-3_standard_vivid.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-Jb7JteoLCiQXABLxGCzg6o">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk">
#         <div id="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-LBaiEmPdjVLGxtfmHcEV29" class="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">standard_natural</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/openai_dall-e-3_standard_natural.png</h4><img src="data/openai_dall-e-3_standard_natural.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-LBaiEmPdjVLGxtfmHcEV29">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk">
#         <div id="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-fmdsUnWoTpL5sJbAzxUaBJ" class="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">hd_vivid</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/openai_dall-e-3_hd_vivid.png</h4><img src="data/openai_dall-e-3_hd_vivid.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-fmdsUnWoTpL5sJbAzxUaBJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk">
#         <div id="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-L5NkYCcY4ZBuWusaW3cHNU" class="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">hd_natural</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/openai_dall-e-3_hd_natural.png</h4><img src="data/openai_dall-e-3_hd_natural.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-L5NkYCcY4ZBuWusaW3cHNU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-AxCtLj4vrXxWwJgYdpBHRk {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-AxCtLj4vrXxWwJgYdpBHRk">
#     <div class="ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk">
#         <div id="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-Jb7JteoLCiQXABLxGCzg6o" class="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">standard_vivid</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/openai_dall-e-3_standard_vivid.png</h4><img src="data/openai_dall-e-3_standard_vivid.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-Jb7JteoLCiQXABLxGCzg6o">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk">
#         <div id="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-LBaiEmPdjVLGxtfmHcEV29" class="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">standard_natural</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/openai_dall-e-3_standard_natural.png</h4><img src="data/openai_dall-e-3_standard_natural.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-LBaiEmPdjVLGxtfmHcEV29">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk">
#         <div id="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-fmdsUnWoTpL5sJbAzxUaBJ" class="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">hd_vivid</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/openai_dall-e-3_hd_vivid.png</h4><img src="data/openai_dall-e-3_hd_vivid.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-fmdsUnWoTpL5sJbAzxUaBJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-AxCtLj4vrXxWwJgYdpBHRk">
#         <div id="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-L5NkYCcY4ZBuWusaW3cHNU" class="ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">hd_natural</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/openai_dall-e-3_hd_natural.png</h4><img src="data/openai_dall-e-3_hd_natural.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-AxCtLj4vrXxWwJgYdpBHRk-L5NkYCcY4ZBuWusaW3cHNU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
